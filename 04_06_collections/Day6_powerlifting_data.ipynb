# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict, namedtuple

# %% [markdown]
# # Powerlifting Data
# I grabbed a powerlifting dataset from kaggle (https://www.kaggle.com/open-powerlifting/powerlifting-database).
#
# It contains two files - (1) meet information and (2) meet results
#
# For those of you that are not familiar with powerlifting - athlete's are judged on 3 lifts: squat, bench, and deadlift.  Each athlete has 3 attempts at each lift, and are competing to achieve the best overall score in a meet.  The overall score is calculated by adding together their best squat, bench and deadlift.
#
# Our goal - answer the following questions:
# 1. What federation has held the most meets to date (past 3 years)?
# 2. What state has held the most meets to date (past 3 years)
# 3. Can we find the top squat, bench, deadlift and total for each weight category?
#
#
# Note: Since we are trying to become more familiar with python Collections, we will try to utilize Counters, defaultdicts, and namedtuples to answer these questions.

# %% [markdown]
# ## Meets

# %%
# load the data
meets = pd.read_csv('./meets.csv')
meets['Date'] = pd.to_datetime(meets.Date)
meets['Year'] = meets.Date.dt.year
meets.head()
# Out:
#    MeetID        MeetPath Federation       Date MeetCountry MeetState  \
# 0       0  365strong/1601  365Strong 2016-10-29         USA        NC
# 1       1  365strong/1602  365Strong 2016-11-19         USA        MO
# 2       2  365strong/1603  365Strong 2016-07-09         USA        NC
# 3       3  365strong/1604  365Strong 2016-06-11         USA        SC
# 4       4  365strong/1605  365Strong 2016-04-10         USA        SC
#
#     MeetTown                                           MeetName  Year
# 0  Charlotte  2016 Junior & Senior National Powerlifting Cha...  2016
# 1      Ozark                  Thanksgiving Powerlifting Classic  2016
# 2  Charlotte                             Charlotte Europa Games  2016
# 3  Rock Hill                   Carolina Cup Push Pull Challenge  2016
# 4  Rock Hill                              Eastern USA Challenge  2016

# %%
for year in sorted(meets.Year.unique(), reverse=True)[:3]:
    print(year)
    print('-----')
    
    # what is the most frequent federation?
    most_frequent_federation = Counter(meets[meets.Year==year].Federation.values)
    for fed in most_frequent_federation.most_common(5):
        print(fed)
# Out:
# 2018
# -----
# ('USAPL', 21)
# ('USPA', 10)
# ('CPU', 3)
# ('GPC-AUS', 3)
# ('RPS', 3)
# 2017
# -----
# ('THSPA', 341)
# ('USAPL', 299)
# ('USPA', 252)
# ('NSF', 100)
# ('PA', 88)
# 2016
# -----
# ('THSPA', 329)
# ('USAPL', 249)
# ('USPA', 213)
# ('NSF', 115)
# ('RPS', 77)

# %%
for year in sorted(meets.Year.unique(), reverse=True)[:3]:
    print(year)
    print('-----')
    
    # what is the most frequent federation?
    most_frequent_state = Counter(meets[meets.Year==year].MeetState.values)
    for state in most_frequent_state.most_common(5):
        print(state)
# Out:
# 2018
# -----
# ('TX', 4)
# ('CA', 4)
# (nan, 3)
# ('MA', 3)
# ('WI', 3)
# 2017
# -----
# ('TX', 392)
# (nan, 197)
# ('CA', 86)
# ('ON', 49)
# ('NY', 47)
# 2016
# -----
# ('TX', 382)
# (nan, 223)
# ('CA', 68)
# ('PA', 42)
# ('OH', 42)

# %% [markdown]
# ## Meet Results

# %%
lifting_results = pd.read_csv('./openpowerlifting.csv')
lifting_results.head()
# Out:
#    MeetID              Name Sex   Equipment   Age     Division  BodyweightKg  \
# 0       0  Angie Belk Terry   F       Wraps  47.0    Mst 45-49         59.60
# 1       0       Dawn Bogart   F  Single-ply  42.0    Mst 40-44         58.51
# 2       0       Dawn Bogart   F  Single-ply  42.0  Open Senior         58.51
# 3       0       Dawn Bogart   F         Raw  42.0  Open Senior         58.51
# 4       0      Destiny Dula   F         Raw  18.0   Teen 18-19         63.68
#
#   WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg  Deadlift4Kg  \
# 0            60       NaN        47.63       NaN        20.41          NaN
# 1            60       NaN       142.88       NaN        95.25          NaN
# 2            60       NaN       142.88       NaN        95.25          NaN
# 3            60       NaN          NaN       NaN        95.25          NaN
# 4          67.5       NaN          NaN       NaN        31.75          NaN
#
#    BestDeadliftKg  TotalKg Place   Wilks
# 0           70.31   138.35     1  155.05
# 1          163.29   401.42     1  456.38
# 2          163.29   401.42     1  456.38
# 3             NaN    95.25     1  108.29
# 4           90.72   122.47     1  130.47

# %% [markdown]
# Powerlifters can lift 'equipped' or 'raw'.  Raw lifters will not use equipment to assist them in lifting (such as knee wraps or specialized singlets).  We will only look at raw results for this analysis.

# %%
lifting_results.Equipment.unique()
# Out:
# array(['Wraps', 'Single-ply', 'Raw', 'Multi-ply', 'Straps'], dtype=object)

# %%
# drop equipped lifters from this analysis
lifting_results = lifting_results[lifting_results.Equipment == 'Raw']
lifting_results.head()
# Out:
#    MeetID                    Name Sex Equipment   Age     Division  \
# 3       0             Dawn Bogart   F       Raw  42.0  Open Senior
# 4       0            Destiny Dula   F       Raw  18.0   Teen 18-19
# 6       0           Maureen Clary   F       Raw  60.0    Mst 60-64
# 7       0           Maureen Clary   F       Raw  60.0  Open Senior
# 9       0  Priscilla Sweat Pardue   F       Raw  52.0       Senior
#
#    BodyweightKg WeightClassKg  Squat4Kg  BestSquatKg  Bench4Kg  BestBenchKg  \
# 3         58.51            60       NaN          NaN       NaN        95.25
# 4         63.68          67.5       NaN          NaN       NaN        31.75
# 6         67.31          67.5       NaN       124.74       NaN        95.25
# 7         67.31          67.5       NaN       124.74       NaN        95.25
# 9         65.95          67.5       NaN          NaN       NaN          NaN
#
#    Deadlift4Kg  BestDeadliftKg  TotalKg Place   Wilks
# 3          NaN             NaN    95.25     1  108.29
# 4          NaN           90.72   122.47     1  130.47
# 6          NaN          163.29   383.28     1  391.98
# 7          NaN          163.29   383.28     1  391.98
# 9          NaN          108.86   108.86     1  112.99

# %% [markdown]
# We also want to look at results that are complete.  We particularly interested in Name, Sex, WeightClassKg, BestSquatKg, BestBenchKg, BestDeadliftKg and Totalkg.

# %%
# merge meet information into dataframe
lifting_results = pd.merge(lifting_results, meets, how='left', left_on='MeetID', right_on='MeetID')

# %%
# take a look at missing data
lifting_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186317 entries, 0 to 186316
# Data columns (total 25 columns):
# MeetID            186317 non-null int64
# Name              186317 non-null object
# Sex               186317 non-null object
# Equipment         186317 non-null object
# Age               99001 non-null float64
# Division          177538 non-null object
# BodyweightKg      185995 non-null float64
# WeightClassKg     185317 non-null object
# Squat4Kg          454 non-null float64
# BestSquatKg       136210 non-null float64
# Bench4Kg          1123 non-null float64
# BestBenchKg       172729 non-null float64
# Deadlift4Kg       1518 non-null float64
# BestDeadliftKg    155816 non-null float64
# TotalKg           179914 non-null float64
# Place             185574 non-null object
# Wilks             179642 non-null float64
# MeetPath          186317 non-null object
# Federation        186317 non-null object
# Date              186317 non-null datetime64[ns]
# MeetCountry       186317 non-null object
# MeetState         156506 non-null object
# MeetTown          123589 non-null object
# MeetName          186317 non-null object
# Year              186317 non-null int64
# dtypes: datetime64[ns](1), float64(10), int64(2), object(12)
# memory usage: 37.0+ MB

# %%
# drop missing data within our specific fields
lifting_results.dropna(subset=['WeightClassKg', 'BestSquatKg', 'BestBenchKg', 'BestDeadliftKg', 'TotalKg', 'Year'], inplace=True)

# %% [markdown]
# Powerlifting also have various weight classes - which are different for male and female.  Let's ensure we only utilize the current IPF weight classes.

# %%
# list weight classes in the current dataset
lifting_results[lifting_results.Sex == 'F'].WeightClassKg.unique()
# Out:
# array(['67.5', '75', '82.5', '90', '52', '60', '56', '90+', '110', '35',
#        '40', '44', '48', '100', '57', '63', '72', '84', '84+', '47', '43',
#        '59', '100+', '53', '80', '74', '105', '66', '83', '110+', '75+',
#        '30', '93', '34'], dtype=object)

# %%
# Define IPF weight classes
mens_weight_classes = ['53', '59', '66', '74', '83', '93', '105', '120', '120+']
womens_weight_classes = ['43', '47', '52', '57', '63', '72', '84', '84+']

# %% [markdown]
# With the data prepped, let's load our data in to a defaultdict for organization.  We will group the meet results by Sex & Weight class.

# %%
# create a namedtuple to represent each lift
Lift = namedtuple('Lift', ['name', 'squat', 'bench', 'deadlift', 'total', 'year'])

# create a namedtuple ro represent each weight class / sex combindation
DClass = namedtuple('DClass', ['weight_class', 'sex'])

# create defaultdict to manage results
results = defaultdict(list)

for index, row in lifting_results.iterrows():
        
    # we will only record a result if the lifter is part of our recognized weight classes
    if ((row.Sex == 'F') & (row.WeightClassKg in womens_weight_classes)) | \
    ((row.Sex =='M') & (row.WeightClassKg in mens_weight_classes)):
            key = DClass(row.WeightClassKg, row.Sex)
            value = Lift(row.Name, row.BestSquatKg, row.BestBenchKg, row.BestDeadliftKg, row.TotalKg, row.Year)               
            
            results[key].append(value)

# %%
# verify our results
results[DClass('53', 'M')]
# Out:
# [Lift(name='Étienne Bergeron', squat=77.5, bench=40.0, deadlift=85.0, total=202.5, year=2011),
#  Lift(name='Étienne Bergeron', squat=85.0, bench=52.5, deadlift=125.0, total=262.5, year=2012),
#  Lift(name='André Albert', squat=102.5, bench=67.5, deadlift=120.0, total=290.0, year=2013),
#  Lift(name='Tom-Alexandre Leroux-Moreau', squat=55.0, bench=32.5, deadlift=72.5, total=160.0, year=2013),
#  Lift(name='Bryce Booker', squat=75.0, bench=40.0, deadlift=95.0, total=210.0, year=2014),
#  Lift(name='Owen Jones', squat=52.5, bench=40.0, deadlift=85.0, total=177.5, year=2015),
#  Lift(name='John Pineda', squat=120.0, bench=92.5, deadlift=142.5, total=355.0, year=2015),
#  Lift(name='Ryan MacKay', squat=45.0, bench=27.5, deadlift=75.0, total=147.5, year=2016),
#  Lift(name='John Pineda', squat=122.5, bench=100.0, deadlift=162.5, total=385.0, year=2016),
#  Lift(name='Ryan MacKay', squat=52.5, bench=32.5, deadlift=80.0, total=165.0, year=2016),
#  Lift(name='Ryan MacKay', squat=55.0, bench=35.0, deadlift=87.5, total=177.5, year=2016),
#  Lift(name='Khan Vu', squat=127.5, bench=112.5, deadlift=167.5, total=407.5, year=2016),
#  Lift(name='Tyson Veniot', squat=117.5, bench=75.0, deadlift=150.0, total=342.5, year=2016),
#  Lift(name='Ryan MacKay', squat=65.0, bench=37.5, deadlift=92.5, total=195.0, year=2016),
#  Lift(name='Colton Matheson', squat=37.5, bench=25.0, deadlift=47.5, total=110.0, year=2016),
#  Lift(name='Darcy Ducharme', squat=162.5, bench=80.0, deadlift=165.0, total=407.5, year=2017),
#  Lift(name='Jeffrey Polasz', squat=145.0, bench=90.0, deadlift=182.5, total=417.5, year=2017),
#  Lift(name='John Pineda', squat=140.0, bench=100.0, deadlift=185.0, total=425.0, year=2017),
#  Lift(name='John Pineda', squat=145.0, bench=100.0, deadlift=192.5, total=437.5, year=2017),
#  Lift(name='John Pineda', squat=142.5, bench=97.5, deadlift=185.0, total=425.0, year=2017),
#  Lift(name='Jeffrey Polasz', squat=147.5, bench=97.5, deadlift=185.0, total=430.0, year=2017),
#  Lift(name='Darcy Ducharme', squat=167.5, bench=87.5, deadlift=160.0, total=415.0, year=2017),
#  Lift(name='Jerome Patrick', squat=60.0, bench=40.0, deadlift=90.0, total=190.0, year=2012),
#  Lift(name='Boris Komissarov', squat=155.0, bench=105.0, deadlift=167.5, total=427.5, year=2015),
#  Lift(name='Egidijus Valciukas', squat=180.0, bench=110.0, deadlift=135.0, total=425.0, year=2015),
#  Lift(name='Nikita Panyuhin', squat=127.5, bench=92.5, deadlift=160.0, total=380.0, year=2015),
#  Lift(name='Michal Anuszek', squat=142.5, bench=77.5, deadlift=152.5, total=372.5, year=2015),
#  Lift(name='Egidijus Valciukas', squat=190.5, bench=120.0, deadlift=140.0, total=450.5, year=2016),
#  Lift(name='Vadym Gutnik', squat=130.0, bench=87.5, deadlift=170.0, total=387.5, year=2016),
#  Lift(name='Dovydas Dargevicius', squat=112.5, bench=65.0, deadlift=140.0, total=317.5, year=2016),
#  Lift(name='Albert Stankevich', squat=105.0, bench=55.0, deadlift=100.0, total=260.0, year=2016),
#  Lift(name='Ilya Marichev', squat=137.5, bench=92.5, deadlift=178.0, total=408.0, year=2017),
#  Lift(name='Albert Stankevich', squat=115.0, bench=62.5, deadlift=65.0, total=242.5, year=2017),
#  Lift(name='Egidijus Valciukas', squat=191.0, bench=115.0, deadlift=135.0, total=441.0, year=2017),
#  Lift(name='Miles Hamimi', squat=77.5, bench=42.5, deadlift=115.0, total=235.0, year=2017),
#  Lift(name='Anthony Blangy', squat=127.5, bench=92.5, deadlift=150.0, total=370.0, year=2017),
#  Lift(name='Thomas Michaud', squat=90.0, bench=52.5, deadlift=97.5, total=240.0, year=2017),
#  Lift(name='Théodore Feuvrier', squat=70.0, bench=47.5, deadlift=95.0, total=212.5, year=2017),
#  Lift(name='Ferdinand Lamare', squat=45.0, bench=32.5, deadlift=75.0, total=152.5, year=2017),
#  Lift(name='Vasyl Gusak', squat=117.5, bench=72.5, deadlift=150.0, total=340.0, year=2013),
#  Lift(name='Sergey Novikov', squat=155.0, bench=92.5, deadlift=187.5, total=435.0, year=2013),
#  Lift(name='Husnuddin Buriev', squat=142.5, bench=100.0, deadlift=170.0, total=412.5, year=2013),
#  Lift(name='Artur Gusakov', squat=102.5, bench=82.5, deadlift=167.5, total=352.5, year=2013),
#  Lift(name='Alexei Kulakov', squat=130.0, bench=85.0, deadlift=162.5, total=377.5, year=2014),
#  Lift(name='Revaldo Matras', squat=120.0, bench=67.5, deadlift=172.5, total=360.0, year=2014),
#  Lift(name='Hakim Riahi', squat=120.0, bench=50.0, deadlift=177.5, total=347.5, year=2014),
#  Lift(name='Akzhol Alymbek Uulu', squat=140.0, bench=110.0, deadlift=187.5, total=437.5, year=2014),
#  Lift(name='Husnuddin Buriev', squat=150.0, bench=115.0, deadlift=172.5, total=437.5, year=2014),
#  Lift(name='Pavel Zayats', squat=100.0, bench=85.0, deadlift=115.0, total=300.0, year=2014),
#  Lift(name='Boris Komissarov', squat=165.0, bench=110.0, deadlift=175.0, total=450.0, year=2015),
#  Lift(name='Egidijus Valciukas', squat=190.0, bench=115.0, deadlift=142.5, total=447.5, year=2015),
#  Lift(name='Dalton LaCoe', squat=157.5, bench=115.0, deadlift=230.0, total=502.5, year=2015),
#  Lift(name='Nicholas Viet', squat=135.0, bench=95.0, deadlift=172.5, total=402.5, year=2015),
#  Lift(name='Yuki Tan', squat=127.5, bench=90.0, deadlift=177.5, total=395.0, year=2015),
#  Lift(name='Aziz Farooqi', squat=145.0, bench=80.0, deadlift=165.0, total=390.0, year=2016),
#  Lift(name='Dalton LaCoe', squat=160.0, bench=117.5, deadlift=240.5, total=518.0, year=2016),
#  Lift(name='Nicholas Viet', squat=160.0, bench=107.5, deadlift=180.0, total=447.5, year=2016),
#  Lift(name='Yuki Tan', squat=135.0, bench=95.0, deadlift=175.0, total=405.0, year=2016),
#  Lift(name='Andrei Poddubniak', squat=162.5, bench=102.5, deadlift=175.0, total=440.0, year=2017),
#  Lift(name='Ilya Marichev', squat=147.5, bench=95.0, deadlift=180.0, total=422.5, year=2017),
#  Lift(name='Ryo Matsuzaki', squat=150.0, bench=85.0, deadlift=175.0, total=410.0, year=2017),
#  Lift(name='Aliaksandr Antonenka', squat=140.0, bench=85.0, deadlift=160.0, total=385.0, year=2017),
#  Lift(name='Masaya Yamada', squat=120.0, bench=95.0, deadlift=155.0, total=370.0, year=2017),
#  Lift(name='Uladzislau Trusevich', squat=115.0, bench=85.0, deadlift=130.0, total=330.0, year=2017),
#  Lift(name='George Diers', squat=112.5, bench=55.0, deadlift=140.0, total=307.5, year=2017),
#  Lift(name='Egidijus Valciukas', squat=200.0, bench=125.0, deadlift=145.0, total=470.0, year=2017),
#  Lift(name='Denis Pavlov', squat=142.5, bench=105.0, deadlift=170.0, total=417.5, year=2017),
#  Lift(name='Taiki Matsui', squat=110.0, bench=65.0, deadlift=150.0, total=325.0, year=2017),
#  Lift(name='Joeshua Ayala', squat=100.0, bench=82.5, deadlift=132.5, total=315.0, year=2017),
#  Lift(name='David Keane', squat=80.0, bench=37.5, deadlift=95.0, total=212.5, year=2017),
#  Lift(name='Steven Keane', squat=62.5, bench=32.5, deadlift=80.0, total=175.0, year=2017),
#  Lift(name='Jesús David Gómez Izquierdo', squat=140.0, bench=87.5, deadlift=182.5, total=410.0, year=2017),
#  Lift(name='Fredrik Eskil Myrvang', squat=120.0, bench=130.0, deadlift=90.0, total=340.0, year=2011),
#  Lift(name='Fredrik Eskil Myrvang', squat=127.5, bench=127.5, deadlift=105.0, total=360.0, year=2011),
#  Lift(name='Cameron Moss', squat=110.0, bench=45.0, deadlift=105.0, total=260.0, year=2012),
#  Lift(name='Brendan Chaithoo', squat=110.0, bench=85.0, deadlift=160.0, total=355.0, year=2015),
#  Lift(name='Brendon Chaithoo', squat=140.0, bench=95.5, deadlift=170.0, total=405.5, year=2016),
#  Lift(name='Brendon Chaithoo', squat=130.0, bench=95.0, deadlift=165.0, total=390.0, year=2016),
#  Lift(name='Fergus Wright', squat=40.0, bench=30.0, deadlift=72.5, total=142.5, year=2017),
#  Lift(name='Brodie Toms', squat=125.0, bench=77.5, deadlift=150.0, total=352.5, year=2017),
#  Lift(name='Nicholas Viet', squat=110.0, bench=77.5, deadlift=152.5, total=340.0, year=2014),
#  Lift(name='Nicholas Viet', squat=142.5, bench=82.5, deadlift=60.0, total=285.0, year=2015),
#  Lift(name='James Kowald', squat=95.0, bench=65.0, deadlift=130.0, total=290.0, year=2016),
#  Lift(name='Brodie Toms', squat=110.0, bench=75.0, deadlift=132.5, total=317.5, year=2017),
#  Lift(name='Brodie Toms', squat=120.0, bench=80.0, deadlift=125.0, total=325.0, year=2017),
#  Lift(name='Saldana Jorge', squat=80.0, bench=60.0, deadlift=135.0, total=275.0, year=2012),
#  Lift(name='Douglas Newcomer Jr', squat=55.0, bench=52.5, deadlift=115.0, total=222.5, year=2012),
#  Lift(name='Riley Walters', squat=65.0, bench=35.0, deadlift=75.0, total=175.0, year=2015),
#  Lift(name='Trevan Craig', squat=81.7, bench=52.2, deadlift=120.2, total=254.0, year=2015),
#  Lift(name='Isaac Hill', squat=60.0, bench=57.5, deadlift=107.5, total=225.0, year=2016),
#  Lift(name='Mekhai Rich', squat=87.5, bench=55.0, deadlift=112.5, total=255.0, year=2016),
#  Lift(name='Christopher Biggs', squat=47.5, bench=35.0, deadlift=80.0, total=162.5, year=2015),
#  Lift(name='Christopher Biggs', squat=65.0, bench=45.0, deadlift=97.5, total=207.5, year=2017),
#  Lift(name='Dominic Osorio', squat=105.0, bench=75.0, deadlift=125.0, total=305.0, year=2016),
#  Lift(name='Elijah Edelman', squat=60.0, bench=32.5, deadlift=77.5, total=170.0, year=2015),
#  Lift(name='Derrick Lien', squat=120.0, bench=82.5, deadlift=157.5, total=360.0, year=2016),
#  Lift(name='Elijah Edelman', squat=67.5, bench=37.5, deadlift=75.0, total=180.0, year=2016),
#  Lift(name='Elijah Edelman', squat=80.0, bench=47.5, deadlift=92.5, total=220.0, year=2016),
#  Lift(name='Lester Philip Nolasco', squat=105.0, bench=72.5, deadlift=142.5, total=320.0, year=2016),
#  Lift(name='Lester Philip Nolasco', squat=117.5, bench=77.5, deadlift=152.5, total=347.5, year=2017),
#  Lift(name='Elijah Edelman', squat=95.0, bench=57.5, deadlift=117.5, total=270.0, year=2017),
#  Lift(name='Alton Parkes', squat=80.0, bench=52.5, deadlift=85.0, total=217.5, year=2017),
#  Lift(name='Lester Philip Nolasco', squat=115.0, bench=75.0, deadlift=147.5, total=337.5, year=2017),
#  Lift(name='Derrick Lien', squat=140.0, bench=85.0, deadlift=165.0, total=390.0, year=2017),
#  Lift(name='Lester Philip Nolasco', squat=127.5, bench=77.5, deadlift=165.0, total=370.0, year=2017),
#  Lift(name='Alton Parkes', squat=87.5, bench=57.5, deadlift=95.0, total=240.0, year=2017),
#  Lift(name='Jonathan Elraheb', squat=72.5, bench=40.0, deadlift=95.0, total=207.5, year=2017),
#  Lift(name='Lester Philip Nolasco', squat=120.0, bench=77.5, deadlift=157.5, total=355.0, year=2017),
#  Lift(name='Jonathan Elraheb', squat=82.5, bench=47.5, deadlift=102.5, total=232.5, year=2017),
#  Lift(name='Malaki Hinde', squat=60.0, bench=50.0, deadlift=67.5, total=177.5, year=2018),
#  Lift(name='Robert Mellen', squat=72.5, bench=60.0, deadlift=102.5, total=235.0, year=2015),
#  Lift(name='Robert Mellen', squat=82.5, bench=65.0, deadlift=102.5, total=250.0, year=2016),
#  Lift(name='Brandon D. Kight', squat=102.5, bench=57.5, deadlift=110.0, total=270.0, year=2015),
#  Lift(name='Shakeem Suarez', squat=80.0, bench=92.5, deadlift=142.5, total=315.0, year=2015),
#  Lift(name='Shakeem Suarez', squat=80.0, bench=92.5, deadlift=142.5, total=315.0, year=2015),
#  Lift(name='Joeshua Ayala-Rodriguez', squat=90.0, bench=60.0, deadlift=115.0, total=265.0, year=2016),
#  Lift(name='Joshua Ayala', squat=100.0, bench=65.0, deadlift=125.0, total=290.0, year=2016),
#  Lift(name='Brandon Kight', squat=110.0, bench=70.0, deadlift=140.0, total=320.0, year=2015),
#  Lift(name='Drew Cargill Jr', squat=42.5, bench=40.0, deadlift=77.5, total=160.0, year=2015),
#  Lift(name='Jakob Perry', squat=92.5, bench=45.0, deadlift=97.5, total=235.0, year=2016),
#  Lift(name='Jakob Perry', squat=80.0, bench=42.5, deadlift=87.5, total=210.0, year=2016),
#  Lift(name='Gabriel Driscoll', squat=87.5, bench=47.5, deadlift=112.5, total=247.5, year=2017),
#  Lift(name='Thomas Dehn', squat=117.5, bench=72.5, deadlift=170.0, total=360.0, year=2017),
#  Lift(name='Dylan Ritter', squat=72.5, bench=47.5, deadlift=102.5, total=222.5, year=2017),
#  Lift(name='Billy Tay', squat=87.5, bench=55.0, deadlift=115.0, total=257.5, year=2017),
#  Lift(name='Logan Satkowski', squat=67.5, bench=37.5, deadlift=72.5, total=177.5, year=2015),
#  Lift(name='Robert Hebert', squat=92.5, bench=82.5, deadlift=122.5, total=297.5, year=2015),
#  Lift(name='Cameron Fileccia', squat=65.0, bench=47.5, deadlift=85.0, total=197.5, year=2016),
#  Lift(name='Connor Gruntz', squat=132.5, bench=87.5, deadlift=152.5, total=372.5, year=2016),
#  Lift(name='Edward Taylor', squat=130.0, bench=82.5, deadlift=155.0, total=367.5, year=2016),
#  Lift(name='Joey Bourgeois', squat=112.5, bench=72.5, deadlift=130.0, total=315.0, year=2016),
#  Lift(name='Connor Gruntz', squat=125.0, bench=70.0, deadlift=135.0, total=330.0, year=2017),
#  Lift(name='Nicholas Rizk', squat=62.5, bench=42.5, deadlift=92.5, total=197.5, year=2015),
#  Lift(name='Kameron Kamel', squat=52.5, bench=47.5, deadlift=87.5, total=187.5, year=2015),
#  Lift(name='Luke Zhao', squat=82.5, bench=60.0, deadlift=112.5, total=255.0, year=2015),
#  Lift(name='Ryan Doyle', squat=77.5, bench=55.0, deadlift=90.0, total=222.5, year=2015),
#  Lift(name='Nicholas Cordeiro', squat=82.5, bench=60.0, deadlift=110.0, total=252.5, year=2015),
#  Lift(name='Ryan Doyle', squat=82.5, bench=52.5, deadlift=90.0, total=225.0, year=2016),
#  Lift(name='Anthony Tranduc', squat=75.0, bench=40.0, deadlift=92.5, total=207.5, year=2016),
#  Lift(name='Tony Tran', squat=145.0, bench=80.0, deadlift=170.0, total=395.0, year=2016),
#  Lift(name='Tony Tran', squat=145.0, bench=80.0, deadlift=170.0, total=395.0, year=2016),
#  Lift(name='Said Elljadidi', squat=85.0, bench=62.5, deadlift=115.0, total=262.5, year=2016),
#  Lift(name='Jacob Scibelli', squat=60.0, bench=32.5, deadlift=85.0, total=177.5, year=2015),
#  Lift(name='Finn Bucci', squat=70.0, bench=45.0, deadlift=105.0, total=220.0, year=2015),
#  Lift(name='Vincent Kenyon', squat=97.5, bench=52.5, deadlift=105.0, total=255.0, year=2018),
#  Lift(name='Hayden Ousley', squat=87.5, bench=42.5, deadlift=115.0, total=245.0, year=2016),
#  Lift(name='Hayden Ousley', squat=132.5, bench=52.5, deadlift=165.0, total=350.0, year=2017),
#  Lift(name='Sandro Serrano', squat=140.0, bench=105.0, deadlift=175.0, total=420.0, year=2015),
#  Lift(name='Wyatt Shabram', squat=25.0, bench=20.0, deadlift=45.0, total=90.0, year=2015),
#  Lift(name='Gunnar Shabram', squat=45.0, bench=30.0, deadlift=62.5, total=137.5, year=2015),
#  Lift(name='Wyatt Hegemann', squat=42.5, bench=37.5, deadlift=70.0, total=150.0, year=2015),
#  Lift(name='Joey Jennings', squat=75.0, bench=57.5, deadlift=110.0, total=242.5, year=2015),
#  Lift(name='Gabe Hobbes', squat=50.0, bench=50.0, deadlift=90.0, total=190.0, year=2015),
#  Lift(name='Runin Garcia', squat=82.5, bench=55.0, deadlift=115.0, total=252.5, year=2016),
#  Lift(name='Azad Naser', squat=97.5, bench=75.0, deadlift=142.5, total=315.0, year=2016),
#  Lift(name='George Diers', squat=82.5, bench=40.0, deadlift=105.0, total=227.5, year=2016),
#  Lift(name='Brian Reyna', squat=87.5, bench=82.5, deadlift=120.0, total=290.0, year=2016),
#  Lift(name='Logan Eden', squat=80.0, bench=77.5, deadlift=102.5, total=260.0, year=2016),
#  Lift(name='Uriel Salas', squat=80.0, bench=65.0, deadlift=137.5, total=282.5, year=2017),
#  Lift(name='Logan Eden', squat=82.5, bench=77.5, deadlift=90.0, total=250.0, year=2017),
#  Lift(name='Colin Becker', squat=67.5, bench=47.5, deadlift=92.5, total=207.5, year=2017),
#  Lift(name='Dylan McDonald', squat=80.0, bench=55.0, deadlift=120.0, total=255.0, year=2017),
#  Lift(name='Larry Moody', squat=82.5, bench=65.0, deadlift=112.5, total=260.0, year=2013),
#  Lift(name='Dalton LaCoe', squat=145.0, bench=105.0, deadlift=220.0, total=470.0, year=2014),
#  Lift(name='Matt Devine', squat=117.5, bench=82.5, deadlift=162.5, total=362.5, year=2015),
#  Lift(name='Zachary Morgan', squat=105.0, bench=65.0, deadlift=147.5, total=317.5, year=2015),
#  Lift(name='Joseph Meranto', squat=105.0, bench=72.5, deadlift=140.0, total=317.5, year=2015),
#  Lift(name='Dalton LaCoe', squat=160.0, bench=110.0, deadlift=232.5, total=502.5, year=2015),
#  Lift(name='Sandro Serrano', squat=130.0, bench=90.0, deadlift=160.0, total=380.0, year=2015),
#  Lift(name='George Diers', squat=80.0, bench=47.5, deadlift=112.5, total=240.0, year=2016),
#  Lift(name='Joshua Ayala', squat=100.0, bench=67.5, deadlift=135.0, total=302.5, year=2016),
#  Lift(name='Brandon Sullivan', squat=140.0, bench=75.0, deadlift=127.5, total=342.5, year=2016),
#  Lift(name='Talon Romero', squat=125.0, bench=92.5, deadlift=175.0, total=392.5, year=2017),
#  Lift(name='Derrick Lien', squat=140.5, bench=90.0, deadlift=160.0, total=390.5, year=2017),
#  Lift(name='Edward Taylor', squat=135.0, bench=75.0, deadlift=147.5, total=357.5, year=2017),
#  Lift(name='Luis Gonzalez', squat=125.0, bench=75.0, deadlift=142.5, total=342.5, year=2017),
#  Lift(name='Patrick Cruz', squat=105.0, bench=65.0, deadlift=142.5, total=312.5, year=2017),
#  Lift(name='Dalton LaCoe', squat=170.0, bench=117.5, deadlift=250.0, total=537.5, year=2017),
#  Lift(name='Jerome Leak', squat=122.5, bench=80.0, deadlift=172.5, total=375.0, year=2017),
#  Lift(name='Lester Philip Nolasco', squat=132.5, bench=80.0, deadlift=152.5, total=365.0, year=2017),
#  Lift(name='Bodie Lacoe', squat=127.5, bench=75.0, deadlift=172.5, total=375.0, year=2017),
#  Lift(name='George Diers', squat=133.0, bench=62.5, deadlift=145.0, total=340.5, year=2017),
#  Lift(name='Tyler Suchomel', squat=77.5, bench=45.0, deadlift=112.5, total=235.0, year=2017),
#  Lift(name='Derek Winans', squat=117.5, bench=95.0, deadlift=175.0, total=387.5, year=2015),
#  Lift(name='Eric Pagnotta', squat=82.5, bench=72.5, deadlift=117.5, total=272.5, year=2015),
#  Lift(name='Joe Endres', squat=95.0, bench=60.0, deadlift=112.5, total=267.5, year=2016),
#  Lift(name='Joe Endres', squat=95.0, bench=60.0, deadlift=112.5, total=267.5, year=2016),
#  Lift(name='Brandon Sullivan', squat=127.5, bench=70.0, deadlift=117.5, total=315.0, year=2016),
#  Lift(name='Ethan Gravino', squat=92.5, bench=60.0, deadlift=97.5, total=250.0, year=2017),
#  Lift(name='Isaac Dutcher', squat=50.0, bench=32.5, deadlift=65.0, total=147.5, year=2017),
#  Lift(name='Isaac Dutcher', squat=55.0, bench=35.0, deadlift=70.0, total=160.0, year=2018),
#  Lift(name='Zachary Morgan', squat=97.5, bench=62.5, deadlift=145.0, total=305.0, year=2015),
#  Lift(name='Zachary Morgan', squat=97.5, bench=62.5, deadlift=145.0, total=305.0, year=2015),
#  Lift(name='Alex Stanwick', squat=102.5, bench=62.5, deadlift=130.0, total=295.0, year=2017),
#  Lift(name='Thomas Malandri', squat=90.5, bench=49.4, deadlift=93.3, total=233.2, year=2015),
#  Lift(name='Shane Venesky', squat=90.5, bench=54.5, deadlift=93.3, total=238.4, year=2015),
#  Lift(name='Joseph Stanek', squat=69.0, bench=46.3, deadlift=93.3, total=208.6, year=2015),
#  Lift(name='Jim Brown', squat=93.3, bench=75.1, deadlift=93.3, total=261.7, year=2015),
#  Lift(name='Temitope Adeyiga', squat=85.4, bench=69.9, deadlift=93.3, total=248.6, year=2015),
#  Lift(name='Ryan Nosal', squat=83.3, bench=75.1, deadlift=88.5, total=246.9, year=2015),
#  Lift(name='Jim Brown', squat=93.3, bench=75.1, deadlift=93.3, total=261.7, year=2015),
#  Lift(name='Will Tripoli', squat=85.0, bench=77.5, deadlift=117.5, total=280.0, year=2017),
#  Lift(name='Talon Romero', squat=120.0, bench=92.5, deadlift=155.0, total=367.5, year=2016),
#  Lift(name='Kellen Tolle', squat=80.0, bench=40.0, deadlift=115.0, total=235.0, year=2017),
#  Lift(name='Zachary Young', squat=60.0, bench=32.5, deadlift=65.0, total=157.5, year=2015),
#  Lift(name='Jose Tovar', squat=40.0, bench=52.5, deadlift=102.5, total=195.0, year=2015),
#  Lift(name='Hayden Chapman', squat=125.0, bench=82.5, deadlift=157.5, total=365.0, year=2016),
#  Lift(name='Justin Dowdy', squat=137.5, bench=85.0, deadlift=147.5, total=370.0, year=2016),
#  Lift(name='Jose Tovar', squat=72.5, bench=57.5, deadlift=107.5, total=237.5, year=2016),
#  Lift(name='John Vasquez IV', squat=97.5, bench=47.5, deadlift=127.5, total=272.5, year=2016),
#  Lift(name='Gabriel Driscoll', squat=82.5, bench=40.0, deadlift=102.5, total=225.0, year=2017),
#  Lift(name='Luis Gonzalez', squat=120.0, bench=72.5, deadlift=135.0, total=327.5, year=2017),
#  Lift(name='Gabriel Driscoll', squat=80.0, bench=45.0, deadlift=102.5, total=227.5, year=2017),
#  Lift(name='Gabriel Driscoll', squat=85.0, bench=47.5, deadlift=107.5, total=240.0, year=2017),
#  Lift(name='Tommy Ngo', squat=127.5, bench=72.5, deadlift=155.0, total=355.0, year=2017),
#  Lift(name='Alexis Lara', squat=102.5, bench=80.0, deadlift=132.5, total=315.0, year=2017),
#  Lift(name='Ty Denges', squat=55.0, bench=32.5, deadlift=67.5, total=155.0, year=2017),
#  Lift(name='Jon Morrison', squat=75.0, bench=65.0, deadlift=95.0, total=235.0, year=2017),
#  Lift(name='Bradley Salinas', squat=105.0, bench=70.0, deadlift=140.0, total=315.0, year=2017),
#  Lift(name='Ty Denges', squat=47.5, bench=32.5, deadlift=67.5, total=147.5, year=2017),
#  Lift(name='Sonny Nguyen', squat=107.5, bench=60.0, deadlift=165.0, total=332.5, year=2018),
#  Lift(name='Ace Ong', squat=112.5, bench=60.0, deadlift=165.0, total=337.5, year=2017),
#  Lift(name='Quincy Teal', squat=65.0, bench=40.0, deadlift=90.0, total=195.0, year=2015),
#  Lift(name='Kyle Harr', squat=52.5, bench=27.5, deadlift=75.0, total=155.0, year=2015),
#  Lift(name='Sahil Oberoi', squat=92.5, bench=60.0, deadlift=137.5, total=290.0, year=2015),
#  Lift(name='Patrick Cruz', squat=105.0, bench=65.0, deadlift=130.0, total=300.0, year=2017),
#  Lift(name='Nick Schoen', squat=45.4, bench=31.8, deadlift=77.1, total=154.2, year=2015),
#  Lift(name='Tyler Suchomel', squat=77.5, bench=45.0, deadlift=105.0, total=227.5, year=2016),
#  Lift(name='Nicholas Kurtz', squat=83.9, bench=61.2, deadlift=113.4, total=258.5, year=2017),
#  Lift(name='Zamian Huffer', squat=47.6, bench=24.9, deadlift=70.3, total=142.8, year=2015),
#  Lift(name='Zamian Huffer', squat=65.0, bench=42.5, deadlift=105.0, total=212.5, year=2017),
#  Lift(name='Cayden Larsen', squat=54.4, bench=34.0, deadlift=74.8, total=163.3, year=2017),
#  Lift(name='Nathaniel Hlavka', squat=43.1, bench=27.2, deadlift=56.7, total=127.0, year=2017),
#  Lift(name='Paysen Larsen', squat=63.5, bench=38.6, deadlift=83.9, total=186.0, year=2017),
#  Lift(name='Eli Realing', squat=43.1, bench=34.0, deadlift=79.4, total=156.5, year=2017),
#  Lift(name='Cayden Larsen', squat=57.5, bench=40.0, deadlift=77.5, total=175.0, year=2018)]

# %% [markdown]
# With the dictionary created, we just need to find the top result per weight class and print the result.  I've created a helper function to print the results below:

# %%
def print_best_lifts(values):

    # sort the values
    best = sorted(values, key=lambda values: values.squat, reverse=True)[0]    
    print('Squat     {}kg by {} ({})'.format(best.squat, best.name, best.year))

    # sort the values
    best = sorted(values, key=lambda values: values.bench, reverse=True)[0]
    print('Bench     {}kg by {} ({})'.format(best.bench, best.name, best.year))

    # sort the values
    best = sorted(values, key=lambda values: values.deadlift, reverse=True)[0]
    print('Deadlift  {}kg by {} ({})'.format(best.deadlift, best.name, best.year))

    # sort the values
    best = sorted(values, key=lambda values: values.total, reverse=True)[0]    
    print('Total     {}kg by {} ({})'.format(best.total, best.name, best.year))

# %%
# loop through womens weight classes
for w in womens_weight_classes:
    print('Sex: F | Weight Class: {}kg'.format(w))
    print('-------------------------------')

    # create key
    key = DClass(w, 'F')
    
    # get values from dictionary
    values = results[key]
    
    # print results
    print_best_lifts(values)    
    print()
    
# loop through mens weight classes
for m in mens_weight_classes:
    print('Sex: M | Weight Class: {}kg'.format(m))
    print('-------------------------------')

    # create key
    key = DClass(m, 'M')
    
    # get values from dictionary
    values = results[key]
    
    # print results
    print_best_lifts(values)    
    print()
# Out:
# Sex: F | Weight Class: 43kg
# -------------------------------
# Squat     102.5kg by Marina Shostachuk (2016)
# Bench     70.0kg by Marina Shostachuk (2016)
# Deadlift  135.0kg by Kozue Nemoto (2015)
# Total     282.5kg by Marina Shostachuk (2016)
#
# Sex: F | Weight Class: 47kg
# -------------------------------
# Squat     152.5kg by Wei-Ling Chen (2015)
# Bench     95.5kg by Hanna Rantala (2017)
# Deadlift  175.5kg by Heather Connor (2017)
# Total     407.5kg by Wei-Ling Chen (2015)
#
# Sex: F | Weight Class: 52kg
# -------------------------------
# Squat     162.5kg by Jenn Rotsinger (2017)
# Bench     110.5kg by Febrose Tsiode (2017)
# Deadlift  190.0kg by Jenn Rotsinger (2017)
# Total     445.0kg by Jenn Rotsinger (2017)
#
# Sex: F | Weight Class: 57kg
# -------------------------------
# Squat     174.5kg by Jennifer Millican (2017)
# Bench     107.5kg by Hui-Chun Wu (2017)
# Deadlift  193.0kg by Jennifer Millican (2017)
# Total     463.0kg by Jennifer Millican (2017)
#
# Sex: F | Weight Class: 63kg
# -------------------------------
# Squat     183.0kg by Rosa Castro (2017)
# Bench     142.5kg by Jennifer Thompson (2017)
# Deadlift  221.0kg by Kimberly Walford (2013)
# Total     490.0kg by Jennifer Thompson (2017)
#
# Sex: F | Weight Class: 72kg
# -------------------------------
# Squat     196.0kg by Ana Castellain (2017)
# Bench     144.0kg by Jennifer Thompson (2017)
# Deadlift  246.0kg by Kimberly Walford (2017)
# Total     549.0kg by Kimberly Walford (2017)
#
# Sex: F | Weight Class: 84kg
# -------------------------------
# Squat     207.0kg by Amanda Lawrence (2017)
# Bench     136.5kg by Ielja Strik (2016)
# Deadlift  230.0kg by Cristi Bartlett (2015)
# Total     542.5kg by Sara Cowan (2017)
#
# Sex: F | Weight Class: 84+kg
# -------------------------------
# Squat     273.0kg by Bonica Lough (2017)
# Bench     151.5kg by Bonica Lough (2017)
# Deadlift  240.0kg by Sarah Brenner #1 (2017)
# Total     652.5kg by Bonica Lough (2015)
#
# Sex: M | Weight Class: 53kg
# -------------------------------
# Squat     200.0kg by Egidijus Valciukas (2017)
# Bench     130.0kg by Fredrik Eskil Myrvang (2011)
# Deadlift  250.0kg by Dalton LaCoe (2017)
# Total     537.5kg by Dalton LaCoe (2017)
#
# Sex: M | Weight Class: 59kg
# -------------------------------
# Squat     245.0kg by Kevin Gray (2017)
# Bench     171.0kg by Sergey Fedosienko (2016)
# Deadlift  271.0kg by Sergey Fedosienko (2016)
# Total     669.5kg by Sergey Fedosienko (2016)
#
# Sex: M | Weight Class: 66kg
# -------------------------------
# Squat     257.5kg by Keith McHoney (2017)
# Bench     188.5kg by Eddie Berglund (2016)
# Deadlift  285.0kg by Clifton Pho (2017)
# Total     692.5kg by Keith McHoney (2017)
#
# Sex: M | Weight Class: 74kg
# -------------------------------
# Squat     270.0kg by Yoshihiro Higa (2017)
# Bench     211.5kg by Daiki Kodama (2017)
# Deadlift  322.0kg by Kjell Egil Bakkelund (2017)
# Total     757.0kg by Kjell Egil Bakkelund (2017)
#
# Sex: M | Weight Class: 83kg
# -------------------------------
# Squat     300.5kg by Russel Orhii (2017)
# Bench     208.5kg by Owen Hubbard (2016)
# Deadlift  340.0kg by Yangsu Ren (2017)
# Total     814.0kg by Brett Gibbs (2017)
#
# Sex: M | Weight Class: 93kg
# -------------------------------
# Squat     340.0kg by Jesse Norris (2016)
# Bench     232.5kg by Dennis Cieri (2012)
# Deadlift  372.5kg by Krzysztof Wierzbicki (2014)
# Total     847.5kg by Krzysztof Wierzbicki (2014)
#
# Sex: M | Weight Class: 105kg
# -------------------------------
# Squat     335.0kg by Bronco Deiranauw (2017)
# Bench     250.0kg by Scott Parsons (2017)
# Deadlift  390.0kg by Krzysztof Wierzbicki (2017)
# Total     890.0kg by Krzysztof Wierzbicki (2017)
#
# Sex: M | Weight Class: 120kg
# -------------------------------
# Squat     386.0kg by Dennis Cornelius (2017)
# Bench     253.0kg by Dennis Cornelius (2016)
# Deadlift  375.0kg by Bryce Krawczyk (2017)
# Total     978.5kg by Dennis Cornelius (2016)
#
# Sex: M | Weight Class: 120+kg
# -------------------------------
# Squat     477.5kg by Ray Williams (2017)
# Bench     277.5kg by Ilyes Boughalem (2017)
# Deadlift  392.5kg by Ray Williams (2017)
# Total     1105.0kg by Ray Williams (2017)
